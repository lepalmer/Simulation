# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Aluminum that's 0.1 inch thick

# %%
mu_al = np.genfromtxt('mass_coeff_al.txt')

# %%
plt.loglog(mu_al[:,0],mu_al[:,1])

# %%
ro_al = 2.70
l_al = 0.01

# %%
I_al = np.exp(-1*mu_al[:,1]*ro_al*l_al)

# %%
(mu_al[:,0]*1000.)[15],I_al[15]
# Out:
# (50.0, 0.99011052566416502)

# %%
plt.loglog(mu_al[:,0]*1000.,I_al)
plt.ylim((1e-10,10))
plt.xlim((1,500))
plt.axvline(x=50,ymin=1e-10,ymax=10)
plt.xlabel('Energy [keV]')
plt.ylabel('Percent Attenuation')
plt.show()

# %%
plt.loglog(mu_al[:,0]*1000.,I_al)
plt.ylim((1e-1,2))
plt.xlim((10,100))
plt.axvline(x=50,ymin=1e-10,ymax=10)
plt.xlabel('Energy [keV]')
plt.ylabel('Percent Attenuation')
plt.show()

# %% [markdown]
# # Galium that's 0.07 cm thick (GaAs Solar Panel)

# %%
mu_ga = np.genfromtxt('mass_coeff_ga.txt')

# %%
ro_ga = 5.91
l_ga = 0.07

# %%
I_ga = np.exp(-1*mu_ga[:,1]*ro_ga*l_ga)

# %%
(mu_ga[:,0]*1000.)[24],I_ga[24]
# Out:
# (50.0, 0.28011887845633821)

# %%
plt.loglog(mu_ga[:,0]*1000.,I_ga)
plt.ylim((1e-1,2))
plt.xlim((50,100))
plt.axvline(x=50,ymin=1e-10,ymax=10)
plt.xlabel('Energy [keV]')
plt.ylabel('Percent Attenuation')

# %%
plt.loglog(mu_ga[:,0]*1000.,mu_ga[:,1])

# %% [markdown]
# #Aluminum that's 0.07 cm thick (aluminum substrate)

# %%
l_al_2 = 0.07

# %%
I_al_2 = np.exp(-1*mu_al[:,1]*ro_al*l_al_2)

# %%
plt.loglog(mu_al[:,0]*1000.,I_al_2)
plt.ylim((1e-10,10))
plt.xlim((10,500))
plt.axvline(x=50,ymin=1e-10,ymax=10)
plt.xlabel('Energy [keV]')
plt.ylabel('Percent Attenuation')
plt.show()

# %%
(mu_al[:,0]*1000)[15],I_al_2[15]
# Out:
# (50.0, 0.93279399594569889)

# %% [markdown]
# #Germanium Substrate that's 0.04 cm thick

# %%
ro_ge = 5.323

# %%
mu_ge = np.genfromtxt('mass_coeff_ge.txt')

# %%
I_ge = np.exp(-1*mu_ge[:,1]*ro_ge*0.04)

# %%
(mu_ge[:,0]*1000)[24],I_ge[24]
# Out:
# (50.0, 0.4916008363550019)

# %%
plt.loglog(mu_ge[:,0]*1000.,I_ge)
plt.ylim((1e-1,2))
plt.xlim((10,500))
plt.axvline(x=50,ymin=1e-10,ymax=10)
plt.xlabel('Energy [keV]')
plt.ylabel('Percent Attenuation')
plt.show()

# %% [markdown]
# # 4 microns Ga and the rest is Al

# %%
l_ga = 0.0004
l_al = 0.07 - l_ga

# %%
I_al = np.exp(-1*mu_al[:,1]*ro_al*l_al)
I_ga = np.exp(-1*mu_ga[:,1]*ro_ga*l_ga)

# %%
plt.loglog(mu_ga[:,0]*1000.,I_ga)
plt.loglog(mu_al[:,0]*1000.,I_al)
plt.ylim((1e-1,2))
plt.xlim((2,100))
plt.axvline(x=50,ymin=1e-10,ymax=10)
plt.xlabel('Energy [keV]')
plt.ylabel('Percent Attenuation')
plt.show()

# %%
len(mu_ga[:,0])
# Out:
# 47

# %%
for i,e in enumerate(mu_ga[:,0]*1000.):
    print e, I_ga[i]
# Out:
# 1.0 0.0181024498326
# 1.05613 0.0293903761518
# 1.1154 0.0449786205948
# 1.1154 8.00899644103e-05
# 1.12877 9.60844652475e-06
# 1.1423 1.5308368673e-06
# 1.1423 2.49742635583e-08
# 1.21752 4.69476821964e-08
# 1.2977 2.9676893428e-07
# 1.2977 3.99761024548e-08
# 1.5 5.98850954902e-06
# 2.0 0.00261769793032
# 3.0 0.123218657328
# 4.0 0.376690267812
# 5.0 0.585269765754
# 6.0 0.721296638369
# 8.0 0.861586966796
# 10.0 0.922311333975
# 10.3671 0.929358830659
# 10.3671 0.592508772604
# 15.0 0.817246366006
# 20.0 0.911322971866
# 30.0 0.970171091547
# 40.0 0.986554939241
# 50.0 0.992754710581
# 60.0 0.99559378398
# 80.0 0.99791641648
# 100.0 0.998772183584
# 150.0 0.99943587238
# 200.0 0.999617341632
# 300.0 0.999734558036
# 400.0 0.999779581296
# 500.0 0.999805319913
# 600.0 0.999823022982
# 800.0 0.999847155442
# 1000.0 0.999863677413
# 1250.0 0.999878521419
# 1500.0 0.999889087271
# 2000.0 0.999902773407
# 3000.0 0.999916365178
# 4000.0 0.999922463806
# 5000.0 0.999925394943
# 6000.0 0.999926742323
# 8000.0 0.999927049621
# 10000.0 0.999926009537
# 15000.0 0.999921991043
# 20000.0 0.999917759822

# %%
for i,e in enumerate(mu_al[:,0]*1000.):
    print e, I_al[i]
# Out:
# 1.0 1.94556810727e-97
# 1.5 1.49763031482e-33
# 1.5596 2.8058900298e-30
# 1.5596 9.88131291682e-324
# 2.0 2.04476364112e-185
# 3.0 4.88940708006e-65
# 4.0 3.79010146241e-30
# 5.0 1.64482416496e-16
# 6.0 3.89103399168e-10
# 8.0 7.80614984707e-05
# 10.0 0.00723270917498
# 15.0 0.224270223338
# 20.0 0.523806614016
# 30.0 0.808985925079
# 40.0 0.898676170672
# 50.0 0.933164900054
# 60.0 0.949135056459
# 80.0 0.962787788956
# 100.0 0.968485693554
# 150.0 0.974437033776
# 200.0 0.977279472652
# 300.0 0.980609203724
# 400.0 0.982719589744
# 500.0 0.984255418467
# 600.0 0.985445438307
# 800.0 0.987226673153
# 1000.0 0.988516876974
# 1250.0 0.98972506831
# 1500.0 0.990636834787
# 2000.0 0.991907263145
# 3000.0 0.993367843277
# 4000.0 0.994180205796
# 5000.0 0.994684764917
# 6000.0 0.995023149764
# 8000.0 0.995430860026
# 10000.0 0.995653487945
# 15000.0 0.995883651484
# 20000.0 0.995934182309

# %% [markdown]
# # Carbon (Fiber?) that's 1cm thick

# %%
mu_c = np.genfromtxt('mass_coeff_c.txt')

# %%
ro_c = 2.267
l_c = 1.0

# %%
I_c = np.exp(-1*mu_c[:,1]*ro_c*l_c)

# %%
plt.loglog(mu_c[:,0]*1000.,I_c)
plt.ylim((1e-4,10))
plt.xlim((10,3e4))
#plt.axvline(x=50,ymin=1e-10,ymax=10)
plt.xlabel('Energy [keV]')
plt.ylabel('Percent Attenuation')
plt.show()

# %%
I_c
# Out:
# array([  0.00000000e+000,   0.00000000e+000,   1.19262614e-298,
#          1.16411749e-089,   6.36601404e-038,   1.49791893e-019,
#          1.65663100e-011,   3.12406008e-005,   4.60970691e-003,
#          1.60462389e-001,   3.67139278e-001,   5.59447606e-001,
#          6.24609141e-001,   6.54321996e-001,   6.72061718e-001,
#          6.94205675e-001,   7.09479412e-001,   7.36854447e-001,
#          7.56831757e-001,   7.85321414e-001,   8.05406774e-001,
#          8.20723468e-001,   8.33038966e-001,   8.51791994e-001,
#          8.65711238e-001,   8.78980734e-001,   8.89222379e-001,
#          9.04204127e-001,   9.22423771e-001,   9.33256226e-001,
#          9.40456052e-001,   9.45565394e-001,   9.52341890e-001,
#          9.56561180e-001,   9.62237805e-001,   9.64924663e-001])

# %%
mu_c[:,0]*1000
# Out:
# array([  1.00000000e+00,   1.50000000e+00,   2.00000000e+00,
#          3.00000000e+00,   4.00000000e+00,   5.00000000e+00,
#          6.00000000e+00,   8.00000000e+00,   1.00000000e+01,
#          1.50000000e+01,   2.00000000e+01,   3.00000000e+01,
#          4.00000000e+01,   5.00000000e+01,   6.00000000e+01,
#          8.00000000e+01,   1.00000000e+02,   1.50000000e+02,
#          2.00000000e+02,   3.00000000e+02,   4.00000000e+02,
#          5.00000000e+02,   6.00000000e+02,   8.00000000e+02,
#          1.00000000e+03,   1.25000000e+03,   1.50000000e+03,
#          2.00000000e+03,   3.00000000e+03,   4.00000000e+03,
#          5.00000000e+03,   6.00000000e+03,   8.00000000e+03,
#          1.00000000e+04,   1.50000000e+04,   2.00000000e+04])
