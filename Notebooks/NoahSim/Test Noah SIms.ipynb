# %%
import fastcube
import GRBgenerator

# %%
sim1 = GRBgenerator.Sky(16, 500)

# %%
cube1 = fastcube.FastCube(1000, 45, alternating=False)

# %%
response = cube1.response2GRB(sim1, samples=5, test=False, talk=True)
# Out:
# Testing [  2.92418036  45.        ]
# Avg loc offset = 7.10399515486 deg.
# Testing [   2.92418036  135.        ]
# Avg loc offset = 6.14594158288 deg.
# Testing [   2.92418036  225.        ]
# Avg loc offset = 7.54460577943 deg.
# Testing [   2.92418036  315.        ]
# Avg loc offset = 6.72053717516 deg.
# Testing [  5.85026706  22.5       ]
# Avg loc offset = 6.23906393443 deg.
# Testing [  5.85026706  67.5       ]
# Avg loc offset = 7.90199754765 deg.
# Testing [   5.85026706  112.5       ]
# Avg loc offset = 9.01730054168 deg.
# Testing [   5.85026706  157.5       ]
# Avg loc offset = 5.10769977055 deg.
# Testing [   5.85026706  202.5       ]
# Avg loc offset = 3.99756308113 deg.
# Testing [   5.85026706  247.5       ]
# Avg loc offset = 6.1646398015 deg.
# Testing [   5.85026706  292.5       ]
# Avg loc offset = 8.09162833914 deg.
# Testing [   5.85026706  337.5       ]
# Avg loc offset = 5.56107325958 deg.
# Testing [  8.78017768  15.        ]
# ...
